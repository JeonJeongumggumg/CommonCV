# %% [markdown]
# <a href="https://colab.research.google.com/github/JeonJeongumggumg/CommonCV/blob/main/GrayScale2Hist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 화질향상
#
# 히스토그램: 특정 사진의 구성 픽셀들의 분포를 시각적으로 표현한 것.(픽셀 위치정보 반영 x)

# %% [markdown]
# hist = cv2.calcHist(images, channels, mask, histsize, ranges)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
src = cv2.imread('/content/drive/MyDrive/교재실습영상/Copy of lena.jpg',0)
hist = cv2.calcHist([src],[0],None,[256],[0,256])
plt.plot(hist)
