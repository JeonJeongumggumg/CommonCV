# %% [markdown]
# <a href="https://colab.research.google.com/github/JeonJeongumggumg/CommonCV/blob/main/adaptiveThreshold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 임계값적용(밝기, 색상차이를 통해 전경과 배경을 분리하는 기본방법)
#
# 사용자에 의해 임계값이 결정 혹은 영상으로부터의 히스토그램을 생성해 자동결정
#
# 적응적 임계값 적용
#
# 하나의 임계값으로 전경-배경구분하는 문제점을 보완하기 위해 블록으로 분할하고 블록마다 제각기 다른 임계값을 적용하는 방법
#
# *적당한 블록의 크기를 결정하는 것이 가장 중요함 *

# %% [markdown]
# cv2.adaptiveThreshold(src,maxValue,adaptiveMethod,thresholdType,blockSize,C)
#
# src: grayscale image
#
# maxValue: 픽셀에 적용될 최대값, 보통 255
#
# adaptiveMethod: thresholding value를 결정하는 계산 방법
#
# blockSize: 블록크기 , 3이상의 홀수(너무 작지 않도록)
#
# C: 블록 내 평균값 혹은 블록 내 가중 평균값에서 뺄 값

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/교재실습영상/Copy of cell.bmp',0)
ret, dst = cv2.threshold(src, 120, 255, cv2.THRESH_BINARY)
dst2 = cv2.adaptiveThreshold(src,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,15,2)
dst3 = cv2.adaptiveThreshold(src,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,15,2)

print(ret)
plt.subplot(2,2,1)
plt.imshow(src,cmap='gray')
plt.subplot(2,2,2)
plt.imshow(dst,cmap='gray')
plt.subplot(2,2,3)
plt.imshow(dst2,cmap='gray')
plt.subplot(2,2,4)
plt.imshow(dst3,cmap='gray')
# Out:
# 120.0
