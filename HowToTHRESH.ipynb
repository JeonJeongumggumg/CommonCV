# %% [markdown]
# <a href="https://colab.research.google.com/github/JeonJeongumggumg/CommonCV/blob/main/HowToTHRESH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 임계값적용(밝기, 색상차이를 통해 전경과 배경을 분리하는 기본방법)
#
# 사용자에 의해 임계값이 결정 혹은 영상으로부터의 히스토그램을 생성해 자동결정

# %% [markdown]
# ret, out = cv2.threshold(img,*threshold*,value,type)
#
# ex) ret,dst = cv2.threshold(src,120,255,cv2.THRESH_BINARY)
#
# Two value of return(ret:임계값, out:결과영상)

# %% [markdown]
# 이진화 TYPE
#
# THRESH_BINARY
#
# THRESH_BINARY_INV
#
# THRESH_TRUNC(임계보다 크면 기존값으로 유지)
#
# THRESH_TOZERO(임계보다 크면 기존값으로 유지, 작으면 0으로)
#
# THRESH_TOZERO_INV(임계값보다 크면 0으로, 작으면 기존값 유지)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
src = cv2.imread('/content/drive/MyDrive/교재실습영상/Copy of cell.bmp',0)
plt.subplot(1,2,1)
plt.imshow(src,cmap='gray')
ret, dst = cv2.threshold(src,120,255,cv2.THRESH_BINARY_INV)
print(ret)
plt.subplot(1,2,2)
plt.imshow(dst,cmap='gray')
plt.show()
# Out:
# 120.0
